# %% [markdown]
# # LLMs Configuration (Non-trainable paramters)
#
# - In this tutorial we will see what configuration parameters can do?

# %%
from getpass import getpass
import os

api_key = getpass("Enter your API key: ")
os.environ['MY_SECRET_KEY'] = api_key

# %%
# Installations
# !pip install google-generativeai

# %%
# Device setup
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# Load Model and Tokenizer
import google.generativeai as genai
model = genai.GenerativeModel('gemini-pro')

# %%
response = genai.generate(
    model="gemini-pro",
    prompt="WHat is capital of pakistan",
    max_output_tokens=100
)

print(response.candidates[0].output)
